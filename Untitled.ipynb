# %%
git add requirements.txt
git commit -m "Add requirements.txt for full project environment"
git push origin main
# Out:
#   Cell In[2], line 1
#     git add requirements.txt
#         ^
# SyntaxError: invalid syntax
